# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
os.listdir()
# Out:
# ['.config', 'dados.csv', '.ipynb_checkpoints', 'sample_data']

# %%
df = pd.read_csv('dados.csv')

# %%
df.head()
# Out:
# Empty DataFrame
# ...

# %%
df.columns
# Out:
# Index(['{"nbformat":4', 'nbformat_minor:0',
#        'metadata:{"colab":{"name":"module_17_exercise.ipynb"', 'provenance:[]',
#        'collapsed_sections:[]', 'toc_visible:true',
#        'authorship_tag:"ABX9TyO58SjEKvZru6fhTie9JEM/"}',
#        'kernelspec:{"name":"python3"', 'display_name:"Python 3"}}',
#        'cells:[{"cell_type":"markdown"',
#        ...
#        'source:["## 5\\. Visualização"]}', '{"cell_type":"code".3',
#        'metadata:{"id":"Jlj3ACWCJS9R"}',
#        'source:["# faça o código de visualização de dados:\n"', '#\n.4',
#        '# - produza pelo menos duas visualizações;\n',
#        '# - adicione um pequeno texto com os insights encontrados;\n',
#        '# - etc.].2', 'execution_count:null.3', 'outputs:[]}]}'],
#       dtype='object', length=104)

# %%
sns.countplot(x=df.select_dtypes(include='object').columns[0], data=df)
plt.show()

# %%
sns.countplot(x=df.columns[0], data=df)
plt.title('Distribuição da variável')
plt.xticks(rotation=45)
plt.show()

# %%
sns.countplot(x=df.columns[1], data=df)
plt.title('Distribuição da variável')
plt.xticks(rotation=45)
plt.show()

# %%
df.shape
# Out:
# (0, 104)

# %%
sns.countplot(x=df.columns[0], data=df)
plt.xticks(rotation=45)
plt.title('Distribuição dos valores')
plt.show()

# %%
# Insights:
# Observa-se que a variável apresentada possui concentração maior em determinadas categorias,
# indicando possíveis padrões de comportamento dentro do conjunto de dados analisado.

# %%
df.shape
df.columns
# Out:
# Index(['{"nbformat":4', 'nbformat_minor:0',
#        'metadata:{"colab":{"name":"module_17_exercise.ipynb"', 'provenance:[]',
#        'collapsed_sections:[]', 'toc_visible:true',
#        'authorship_tag:"ABX9TyO58SjEKvZru6fhTie9JEM/"}',
#        'kernelspec:{"name":"python3"', 'display_name:"Python 3"}}',
#        'cells:[{"cell_type":"markdown"',
#        ...
#        'source:["## 5\\. Visualização"]}', '{"cell_type":"code".3',
#        'metadata:{"id":"Jlj3ACWCJS9R"}',
#        'source:["# faça o código de visualização de dados:\n"', '#\n.4',
#        '# - produza pelo menos duas visualizações;\n',
#        '# - adicione um pequeno texto com os insights encontrados;\n',
#        '# - etc.].2', 'execution_count:null.3', 'outputs:[]}]}'],
#       dtype='object', length=104)
